# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 15.5 MB/s eta 0:00:01
# Collecting numpy>=1.22.4
#   Downloading numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      |████████████████████████████████| 18.2 MB 116.5 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 102.8 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 106.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/miniconda/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/user/miniconda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import csv
import pandas as pd

# Directory paths
small_talk_wav_dir = 'dataset_amazigh/wav/conv_wav'
annotations_dir = 'dataset_amazigh/annotations'

# Create the annotations directory if it doesn't exist
os.makedirs(annotations_dir, exist_ok=True)

# List of translations for general small talk phrases
small_talk_translations = [
    ("conv_1.wav", "مرحبًا! كيف حالك؟", "Hello! How are you?"),
    ("conv_2.wav", "أنا بخير، شكرًا. وأنت؟", "I'm fine, thank you. And you?"),
    ("conv_3.wav", "ما اسمك؟", "What's your name?"),
    ("conv_4.wav", "اسمي [اسم]. سعيد بلقائك.", "My name is [Name]. Nice to meet you."),
    ("conv_5.wav", "من أين أنت؟", "Where are you from?"),
    ("conv_6.wav", "أنا من [البلد].", "I'm from [Country]."),
    ("conv_7.wav", "ماذا تعمل؟", "What do you do for a living?"),
    ("conv_8.wav", "أعمل كـ [مهنة].", "I work as a [Profession]."),
    ("conv_9.wav", "هل تحب العيش هنا؟", "Do you like living here?"),
    ("conv_10.wav", "نعم، إنه مكان جميل.", "Yes, it's a beautiful place."),
    ("conv_11.wav", "ما هي هواياتك؟", "What are your hobbies?"),
    ("conv_12.wav", "أستمتع بالقراءة والسفر.", "I enjoy reading and traveling."),
    ("conv_13.wav", "ما هو طعامك المفضل؟", "What's your favorite food?"),
    ("conv_14.wav", "أحب [الطعام].", "I love [Food]."),
    ("conv_15.wav", "هل لديك حيوانات أليفة؟", "Do you have any pets?"),
    ("conv_16.wav", "نعم، لدي كلب.", "Yes, I have a dog."),
    ("conv_17.wav", "كيف كان يومك؟", "How was your day?"),
    ("conv_18.wav", "كان جيدًا، شكرًا.", "It was good, thank you."),
    ("conv_19.wav", "ما هي خططك لعطلة نهاية الأسبوع؟", "What are your plans for the weekend?"),
    ("conv_20.wav", "أخطط لزيارة عائلتي.", "I'm planning to visit my family."),
    ("conv_21.wav", "هل زرت هذا المكان من قبل؟", "Have you visited this place before?"),
    ("conv_22.wav", "نعم، زرته العام الماضي.", "Yes, I visited it last year."),
    ("conv_23.wav", "ما هو فيلمك المفضل؟", "What's your favorite movie?"),
    ("conv_24.wav", "أحب فيلم [الفيلم].", "I love the movie [Movie]."),
    ("conv_25.wav", "ما هو كتابك المفضل؟", "What's your favorite book?"),
    ("conv_26.wav", "أحب كتاب [الكتاب].", "I love the book [Book]."),
    ("conv_27.wav", "كيف هو الطقس اليوم؟", "How is the weather today?"),
    ("conv_28.wav", "الطقس جميل ومشمس.", "The weather is beautiful and sunny."),
    ("conv_29.wav", "هل تحب الرياضة؟", "Do you like sports?"),
    ("conv_30.wav", "نعم، أحب كرة القدم.", "Yes, I love football."),
    ("conv_31.wav", "ما هي مدينتك المفضلة؟", "What's your favorite city?"),
    ("conv_32.wav", "أحب مدينة [المدينة].", "I love the city [City]."),
    ("conv_33.wav", "هل تحب السفر؟", "Do you like traveling?"),
    ("conv_34.wav", "نعم، أحب استكشاف أماكن جديدة.", "Yes, I love exploring new places."),
    ("conv_35.wav", "ما هو لونك المفضل؟", "What's your favorite color?"),
    ("conv_36.wav", "أحب اللون الأزرق.", "I love the color blue."),
    ("conv_37.wav", "هل تعرف أي مطاعم جيدة هنا؟", "Do you know any good restaurants around here?"),
    ("conv_38.wav", "نعم، يوجد مطعم رائع في هذا الشارع.", "Yes, there's a great restaurant down this street."),
    ("conv_39.wav", "هل لديك إخوة أو أخوات؟", "Do you have any siblings?"),
    ("conv_40.wav", "نعم، لدي أخت وأخ.", "Yes, I have a sister and a brother."),
    ("conv_41.wav", "ما هو نوع الموسيقى الذي تفضله؟", "What kind of music do you like?"),
    ("conv_42.wav", "أحب الموسيقى الكلاسيكية.", "I love classical music."),
]

# Adding S1, S2, and S3 variations
sets = ["S1", "S2", "S3"]
all_small_talk_translations = []

for set_prefix in sets:
    for idx, translation in enumerate(small_talk_translations):
        filename = f"{set_prefix}_{translation[0]}"
        arabic_translation, english_translation = translation[1], translation[2]
        all_small_talk_translations.append((filename, arabic_translation, english_translation))

# Filter out files that do not exist
valid_small_talk_entries = []
for entry in all_small_talk_translations:
    file_path = os.path.join(small_talk_wav_dir, entry[0])
    if os.path.exists(file_path):
        valid_small_talk_entries.append(entry)
    else:
        print(f"File not found: {file_path}")

# Write the valid entries to the CSV file
csv_path = os.path.join(annotations_dir, 'small_talk.csv')
with open(csv_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["filename", "translation_arabic", "translation_english"])
    writer.writerows(valid_small_talk_entries)

# Output the table as a pandas DataFrame
df = pd.DataFrame(valid_small_talk_entries, columns=["filename", "translation_arabic", "translation_english"])
print(df)

print(f"\nCSV file created at: {csv_path}")
# Out:
# File not found: dataset_amazigh/wav/conv_wav/S1_conv_12.wav
# File not found: dataset_amazigh/wav/conv_wav/S1_conv_13.wav
# File not found: dataset_amazigh/wav/conv_wav/S1_conv_14.wav
# File not found: dataset_amazigh/wav/conv_wav/S1_conv_27.wav
# File not found: dataset_amazigh/wav/conv_wav/S1_conv_34.wav
# File not found: dataset_amazigh/wav/conv_wav/S1_conv_36.wav
# File not found: dataset_amazigh/wav/conv_wav/S1_conv_42.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_11.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_12.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_14.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_15.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_18.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_19.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_20.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_21.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_22.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_23.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_24.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_25.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_26.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_27.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_28.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_29.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_30.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_31.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_32.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_33.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_34.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_35.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_36.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_37.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_38.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_39.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_40.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_41.wav
# File not found: dataset_amazigh/wav/conv_wav/S2_conv_42.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_5.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_11.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_12.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_15.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_17.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_18.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_19.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_20.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_21.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_22.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_23.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_24.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_25.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_26.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_27.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_28.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_29.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_30.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_31.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_32.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_33.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_34.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_35.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_36.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_37.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_38.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_39.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_40.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_41.wav
# File not found: dataset_amazigh/wav/conv_wav/S3_conv_42.wav
#           filename                  translation_arabic  \
# 0    S1_conv_1.wav                   مرحبًا! كيف حالك؟
# 1    S1_conv_2.wav              أنا بخير، شكرًا. وأنت؟
# 2    S1_conv_3.wav                            ما اسمك؟
# 3    S1_conv_4.wav            اسمي [اسم]. سعيد بلقائك.
# 4    S1_conv_5.wav                         من أين أنت؟
# 5    S1_conv_6.wav                     أنا من [البلد].
# 6    S1_conv_7.wav                          ماذا تعمل؟
# 7    S1_conv_8.wav                     أعمل كـ [مهنة].
# 8    S1_conv_9.wav                   هل تحب العيش هنا؟
# 9   S1_conv_10.wav                 نعم، إنه مكان جميل.
# 10  S1_conv_11.wav                      ما هي هواياتك؟
# 11  S1_conv_15.wav              هل لديك حيوانات أليفة؟
# 12  S1_conv_16.wav                       نعم، لدي كلب.
# 13  S1_conv_17.wav                       كيف كان يومك؟
# 14  S1_conv_18.wav                   كان جيدًا، شكرًا.
# 15  S1_conv_19.wav     ما هي خططك لعطلة نهاية الأسبوع؟
# 16  S1_conv_20.wav                 أخطط لزيارة عائلتي.
# 17  S1_conv_21.wav           هل زرت هذا المكان من قبل؟
# 18  S1_conv_22.wav             نعم، زرته العام الماضي.
# 19  S1_conv_23.wav                 ما هو فيلمك المفضل؟
# 20  S1_conv_24.wav                  أحب فيلم [الفيلم].
# 21  S1_conv_25.wav                 ما هو كتابك المفضل؟
# 22  S1_conv_26.wav                  أحب كتاب [الكتاب].
# 23  S1_conv_28.wav                   الطقس جميل ومشمس.
# 24  S1_conv_29.wav                     هل تحب الرياضة؟
# 25  S1_conv_30.wav                 نعم، أحب كرة القدم.
# 26  S1_conv_31.wav               ما هي مدينتك المفضلة؟
# 27  S1_conv_32.wav                أحب مدينة [المدينة].
# 28  S1_conv_33.wav                       هل تحب السفر؟
# 29  S1_conv_35.wav                  ما هو لونك المفضل؟
# 30  S1_conv_37.wav          هل تعرف أي مطاعم جيدة هنا؟
# 31  S1_conv_38.wav  نعم، يوجد مطعم رائع في هذا الشارع.
# 32  S1_conv_39.wav              هل لديك إخوة أو أخوات؟
# 33  S1_conv_40.wav                   نعم، لدي أخت وأخ.
# 34  S1_conv_41.wav      ما هو نوع الموسيقى الذي تفضله؟
# 35   S2_conv_1.wav                   مرحبًا! كيف حالك؟
# 36   S2_conv_2.wav              أنا بخير، شكرًا. وأنت؟
# 37   S2_conv_3.wav                            ما اسمك؟
# 38   S2_conv_4.wav            اسمي [اسم]. سعيد بلقائك.
# 39   S2_conv_5.wav                         من أين أنت؟
# 40   S2_conv_6.wav                     أنا من [البلد].
# 41   S2_conv_7.wav                          ماذا تعمل؟
# 42   S2_conv_8.wav                     أعمل كـ [مهنة].
# 43   S2_conv_9.wav                   هل تحب العيش هنا؟
# 44  S2_conv_10.wav                 نعم، إنه مكان جميل.
# 45  S2_conv_13.wav                 ما هو طعامك المفضل؟
# 46  S2_conv_16.wav                       نعم، لدي كلب.
# 47  S2_conv_17.wav                       كيف كان يومك؟
# 48   S3_conv_1.wav                   مرحبًا! كيف حالك؟
# 49   S3_conv_2.wav              أنا بخير، شكرًا. وأنت؟
# 50   S3_conv_3.wav                            ما اسمك؟
# 51   S3_conv_4.wav            اسمي [اسم]. سعيد بلقائك.
# 52   S3_conv_6.wav                     أنا من [البلد].
# 53   S3_conv_7.wav                          ماذا تعمل؟
# 54   S3_conv_8.wav                     أعمل كـ [مهنة].
# 55   S3_conv_9.wav                   هل تحب العيش هنا؟
# 56  S3_conv_10.wav                 نعم، إنه مكان جميل.
# 57  S3_conv_13.wav                 ما هو طعامك المفضل؟
# 58  S3_conv_14.wav                       أحب [الطعام].
# 59  S3_conv_16.wav                       نعم، لدي كلب.
#
#                                   translation_english
# 0                                 Hello! How are you?
# 1                       I'm fine, thank you. And you?
# 2                                   What's your name?
# 3                My name is [Name]. Nice to meet you.
# 4                                 Where are you from?
# 5                                 I'm from [Country].
# 6                        What do you do for a living?
# 7                           I work as a [Profession].
# 8                            Do you like living here?
# 9                        Yes, it's a beautiful place.
# 10                             What are your hobbies?
# 11                              Do you have any pets?
# 12                                 Yes, I have a dog.
# 13                                  How was your day?
# 14                            It was good, thank you.
# 15               What are your plans for the weekend?
# 16                   I'm planning to visit my family.
# 17                Have you visited this place before?
# 18                       Yes, I visited it last year.
# 19                        What's your favorite movie?
# 20                          I love the movie [Movie].
# 21                         What's your favorite book?
# 22                            I love the book [Book].
# 23                The weather is beautiful and sunny.
# 24                                Do you like sports?
# 25                              Yes, I love football.
# 26                         What's your favorite city?
# 27                            I love the city [City].
# 28                             Do you like traveling?
# 29                        What's your favorite color?
# 30      Do you know any good restaurants around here?
# 31  Yes, there's a great restaurant down this street.
# 32                          Do you have any siblings?
# 33                Yes, I have a sister and a brother.
# 34                    What kind of music do you like?
# 35                                Hello! How are you?
# 36                      I'm fine, thank you. And you?
# 37                                  What's your name?
# 38               My name is [Name]. Nice to meet you.
# 39                                Where are you from?
# 40                                I'm from [Country].
# 41                       What do you do for a living?
# 42                          I work as a [Profession].
# 43                           Do you like living here?
# 44                       Yes, it's a beautiful place.
# 45                         What's your favorite food?
# 46                                 Yes, I have a dog.
# 47                                  How was your day?
# 48                                Hello! How are you?
# 49                      I'm fine, thank you. And you?
# 50                                  What's your name?
# 51               My name is [Name]. Nice to meet you.
# 52                                I'm from [Country].
# 53                       What do you do for a living?
# 54                          I work as a [Profession].
# 55                           Do you like living here?
# 56                       Yes, it's a beautiful place.
# 57                         What's your favorite food?
# 58                                     I love [Food].
# 59                                 Yes, I have a dog.
#
# CSV file created at: dataset_amazigh/annotations/small_talk.csv
